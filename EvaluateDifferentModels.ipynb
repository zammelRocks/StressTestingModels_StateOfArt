# %% [markdown]
# # Claim Verification with Ollama + Justification Metrics
#
# This notebook:
# 1. Reads a **JSON** dataset of claims with `claim`, `label`, `justification`.
# 2. Calls a local **Ollama** model to predict a **label** (Supported/Refuted) **and** a **justification**.
# 3. Computes **ROUGE-L F1**, **BLEU**, **cosine similarity** (SBERT; fallback TF-IDF), and **BERTScore-F1** between model justification and ground-truth justification.
# 4. Produces a DataFrame with columns:
#    - `claim`, `label`, `justification`
#    - `label_pred`, `justification_pred`
#    - `rougeL_f1`, `bleu`, `cosine`, `bertscore_f1`
# 5. Saves results to `runs/<model_slug>_claim_eval.csv`.

# %%
# !pip install jupyter ipykernel requests pandas tqdm  rouge-score sacrebleu bert-score
# Out:
# Requirement already satisfied: jupyter in c:\users\edupa\miniforge3\lib\site-packages (1.1.1)
# Requirement already satisfied: ipykernel in c:\users\edupa\miniforge3\lib\site-packages (6.30.1)
# Requirement already satisfied: requests in c:\users\edupa\miniforge3\lib\site-packages (2.32.3)
# Requirement already satisfied: pandas in c:\users\edupa\miniforge3\lib\site-packages (2.2.3)
# Requirement already satisfied: tqdm in c:\users\edupa\miniforge3\lib\site-packages (4.67.1)
# Requirement already satisfied: rouge-score in c:\users\edupa\miniforge3\lib\site-packages (0.1.2)
# Requirement already satisfied: sacrebleu in c:\users\edupa\miniforge3\lib\site-packages (2.5.1)
# Requirement already satisfied: bert-score in c:\users\edupa\miniforge3\lib\site-packages (0.3.13)
# Requirement already satisfied: notebook in c:\users\edupa\miniforge3\lib\site-packages (from jupyter) (7.4.5)
# Requirement already satisfied: jupyter-console in c:\users\edupa\miniforge3\lib\site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\edupa\miniforge3\lib\site-packages (from jupyter) (7.16.6)
# Requirement already satisfied: ipywidgets in c:\users\edupa\miniforge3\lib\site-packages (from jupyter) (8.1.7)
# Requirement already satisfied: jupyterlab in c:\users\edupa\miniforge3\lib\site-packages (from jupyter) (4.4.7)
# Requirement already satisfied: comm>=0.1.1 in c:\users\edupa\miniforge3\lib\site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\edupa\miniforge3\lib\site-packages (from ipykernel) (1.8.17)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\edupa\miniforge3\lib\site-packages (from ipykernel) (8.12.3)
# Requirement already satisfied: jupyter-client>=8.0.0 in c:\users\edupa\miniforge3\lib\site-packages (from ipykernel) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\edupa\miniforge3\lib\site-packages (from ipykernel) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\edupa\miniforge3\lib\site-packages (from ipykernel) (0.1.7)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\edupa\miniforge3\lib\site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging>=22 in c:\users\edupa\miniforge3\lib\site-packages (from ipykernel) (24.2)
# Requirement already satisfied: psutil>=5.7 in c:\users\edupa\miniforge3\lib\site-packages (from ipykernel) (7.1.0)
# Requirement already satisfied: pyzmq>=25 in c:\users\edupa\miniforge3\lib\site-packages (from ipykernel) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in c:\users\edupa\miniforge3\lib\site-packages (from ipykernel) (6.5.2)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\edupa\miniforge3\lib\site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\edupa\miniforge3\lib\site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\edupa\miniforge3\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\edupa\miniforge3\lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\edupa\miniforge3\lib\site-packages (from requests) (2025.8.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\edupa\miniforge3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\edupa\miniforge3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\edupa\miniforge3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\edupa\miniforge3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: colorama in c:\users\edupa\miniforge3\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: absl-py in c:\users\edupa\miniforge3\lib\site-packages (from rouge-score) (2.3.1)
# Requirement already satisfied: nltk in c:\users\edupa\miniforge3\lib\site-packages (from rouge-score) (3.9.1)
# Requirement already satisfied: six>=1.14.0 in c:\users\edupa\miniforge3\lib\site-packages (from rouge-score) (1.17.0)
# Requirement already satisfied: portalocker in c:\users\edupa\miniforge3\lib\site-packages (from sacrebleu) (3.2.0)
# Requirement already satisfied: regex in c:\users\edupa\miniforge3\lib\site-packages (from sacrebleu) (2025.9.18)
# Requirement already satisfied: tabulate>=0.8.9 in c:\users\edupa\miniforge3\lib\site-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: lxml in c:\users\edupa\miniforge3\lib\site-packages (from sacrebleu) (6.0.2)
# Requirement already satisfied: torch>=1.0.0 in c:\users\edupa\miniforge3\lib\site-packages (from bert-score) (2.7.0)
# Requirement already satisfied: transformers>=3.0.0 in c:\users\edupa\miniforge3\lib\site-packages (from bert-score) (4.56.2)
# Requirement already satisfied: matplotlib in c:\users\edupa\miniforge3\lib\site-packages (from bert-score) (3.10.3)
# Requirement already satisfied: backcall in c:\users\edupa\miniforge3\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.2.0)
# Requirement already satisfied: decorator in c:\users\edupa\miniforge3\lib\site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\edupa\miniforge3\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: pickleshare in c:\users\edupa\miniforge3\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\edupa\miniforge3\lib\site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\edupa\miniforge3\lib\site-packages (from ipython>=7.23.1->ipykernel) (2.19.2)
# Requirement already satisfied: stack-data in c:\users\edupa\miniforge3\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\edupa\miniforge3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\edupa\miniforge3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (311)
# Requirement already satisfied: filelock in c:\users\edupa\miniforge3\lib\site-packages (from torch>=1.0.0->bert-score) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\edupa\miniforge3\lib\site-packages (from torch>=1.0.0->bert-score) (4.13.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\edupa\miniforge3\lib\site-packages (from torch>=1.0.0->bert-score) (1.14.0)
# Requirement already satisfied: networkx in c:\users\edupa\miniforge3\lib\site-packages (from torch>=1.0.0->bert-score) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\edupa\miniforge3\lib\site-packages (from torch>=1.0.0->bert-score) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\edupa\miniforge3\lib\site-packages (from torch>=1.0.0->bert-score) (2025.5.1)
# Requirement already satisfied: setuptools in c:\users\edupa\miniforge3\lib\site-packages (from torch>=1.0.0->bert-score) (75.8.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in c:\users\edupa\miniforge3\lib\site-packages (from transformers>=3.0.0->bert-score) (0.35.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\edupa\miniforge3\lib\site-packages (from transformers>=3.0.0->bert-score) (6.0.2)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\edupa\miniforge3\lib\site-packages (from transformers>=3.0.0->bert-score) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\edupa\miniforge3\lib\site-packages (from transformers>=3.0.0->bert-score) (0.6.2)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\edupa\miniforge3\lib\site-packages (from ipywidgets->jupyter) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\edupa\miniforge3\lib\site-packages (from ipywidgets->jupyter) (3.0.15)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\edupa\miniforge3\lib\site-packages (from jupyterlab->jupyter) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\edupa\miniforge3\lib\site-packages (from jupyterlab->jupyter) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\edupa\miniforge3\lib\site-packages (from jupyterlab->jupyter) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\edupa\miniforge3\lib\site-packages (from jupyterlab->jupyter) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\edupa\miniforge3\lib\site-packages (from jupyterlab->jupyter) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\edupa\miniforge3\lib\site-packages (from jupyterlab->jupyter) (0.2.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\edupa\miniforge3\lib\site-packages (from matplotlib->bert-score) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\edupa\miniforge3\lib\site-packages (from matplotlib->bert-score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\edupa\miniforge3\lib\site-packages (from matplotlib->bert-score) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\edupa\miniforge3\lib\site-packages (from matplotlib->bert-score) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\users\edupa\miniforge3\lib\site-packages (from matplotlib->bert-score) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\edupa\miniforge3\lib\site-packages (from matplotlib->bert-score) (3.2.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\edupa\miniforge3\lib\site-packages (from nbconvert->jupyter) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\edupa\miniforge3\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\edupa\miniforge3\lib\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\edupa\miniforge3\lib\site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\edupa\miniforge3\lib\site-packages (from nbconvert->jupyter) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\edupa\miniforge3\lib\site-packages (from nbconvert->jupyter) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\edupa\miniforge3\lib\site-packages (from nbconvert->jupyter) (0.10.2)
# Requirement already satisfied: nbformat>=5.7 in c:\users\edupa\miniforge3\lib\site-packages (from nbconvert->jupyter) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\edupa\miniforge3\lib\site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: click in c:\users\edupa\miniforge3\lib\site-packages (from nltk->rouge-score) (8.1.8)
# Requirement already satisfied: joblib in c:\users\edupa\miniforge3\lib\site-packages (from nltk->rouge-score) (1.5.2)
# Requirement already satisfied: webencodings in c:\users\edupa\miniforge3\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\edupa\miniforge3\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (1.4.0)
# Requirement already satisfied: anyio in c:\users\edupa\miniforge3\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (4.11.0)
# Requirement already satisfied: httpcore==1.* in c:\users\edupa\miniforge3\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\edupa\miniforge3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter) (0.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\edupa\miniforge3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.5)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\edupa\miniforge3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\edupa\miniforge3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\edupa\miniforge3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.5.3)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\edupa\miniforge3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.23.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\edupa\miniforge3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0.0)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\edupa\miniforge3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\edupa\miniforge3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\edupa\miniforge3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\users\edupa\miniforge3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\edupa\miniforge3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\edupa\miniforge3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (4.25.1)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\edupa\miniforge3\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter) (2.21.2)
# Requirement already satisfied: wcwidth in c:\users\edupa\miniforge3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel) (0.2.14)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\edupa\miniforge3\lib\site-packages (from sympy>=1.13.3->torch>=1.0.0->bert-score) (1.3.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\edupa\miniforge3\lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.8)
# Requirement already satisfied: executing>=1.2.0 in c:\users\edupa\miniforge3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\edupa\miniforge3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (3.0.0)
# Requirement already satisfied: pure_eval in c:\users\edupa\miniforge3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (0.2.3)
# Requirement already satisfied: sniffio>=1.1 in c:\users\edupa\miniforge3\lib\site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab->jupyter) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\edupa\miniforge3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\edupa\miniforge3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\edupa\miniforge3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\edupa\miniforge3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\edupa\miniforge3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.27.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\edupa\miniforge3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.3.0)
# Requirement already satisfied: rfc3339-validator in c:\users\edupa\miniforge3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\edupa\miniforge3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\edupa\miniforge3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\edupa\miniforge3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\edupa\miniforge3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in c:\users\edupa\miniforge3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.1.0)
# Requirement already satisfied: uri-template in c:\users\edupa\miniforge3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\edupa\miniforge3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\edupa\miniforge3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\edupa\miniforge3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.22)
# Requirement already satisfied: lark>=1.2.2 in c:\users\edupa\miniforge3\lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\edupa\miniforge3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\edupa\miniforge3\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.9.0.20250822)

# %%
# !pip install sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\edupa\miniforge3\lib\site-packages (5.1.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\edupa\miniforge3\lib\site-packages (from sentence-transformers) (4.56.2)
# Requirement already satisfied: tqdm in c:\users\edupa\miniforge3\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\edupa\miniforge3\lib\site-packages (from sentence-transformers) (2.7.0)
# Requirement already satisfied: scikit-learn in c:\users\edupa\miniforge3\lib\site-packages (from sentence-transformers) (1.7.2)
# Requirement already satisfied: scipy in c:\users\edupa\miniforge3\lib\site-packages (from sentence-transformers) (1.16.2)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\edupa\miniforge3\lib\site-packages (from sentence-transformers) (0.35.1)
# Requirement already satisfied: Pillow in c:\users\edupa\miniforge3\lib\site-packages (from sentence-transformers) (11.2.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\edupa\miniforge3\lib\site-packages (from sentence-transformers) (4.13.2)
# Requirement already satisfied: filelock in c:\users\edupa\miniforge3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\edupa\miniforge3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.5.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\edupa\miniforge3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\edupa\miniforge3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in c:\users\edupa\miniforge3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\edupa\miniforge3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx in c:\users\edupa\miniforge3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\edupa\miniforge3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\edupa\miniforge3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (75.8.2)
# Requirement already satisfied: colorama in c:\users\edupa\miniforge3\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: numpy>=1.17 in c:\users\edupa\miniforge3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\edupa\miniforge3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.9.18)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\edupa\miniforge3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\edupa\miniforge3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\edupa\miniforge3\lib\site-packages (from scikit-learn->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\edupa\miniforge3\lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\edupa\miniforge3\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\edupa\miniforge3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\edupa\miniforge3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\edupa\miniforge3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\edupa\miniforge3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\edupa\miniforge3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.8.3)

# %%
DATASET_PATH = "refuted_claims.json"   # your file
MODEL = "gemma3:4b "          # or qwen3:4b / mistral:7b / gemma3:4b
LANG = "en"                    # for BERTScore baseline rescaling

# %%
from pathlib import Path
import json, re, time
from typing import Dict, Any, List, Tuple, Optional

import pandas as pd
import numpy as np

# HTTP (Ollama)
try:
    import requests
except Exception:
    requests = None
import urllib.request, urllib.error

# Metrics
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer  # fallback if SBERT unavailable

# Optional libraries (guarded imports)
try:
    from sentence_transformers import SentenceTransformer
except Exception:
    SentenceTransformer = None

try:
    from bert_score import score as bertscore_score
except Exception:
    bertscore_score = None

try:
    import sacrebleu
except Exception:
    sacrebleu = None

try:
    from rouge_score import rouge_scorer
except Exception:
    rouge_scorer = None

# Optional progress bar (if not installed, you can set USE_TQDM=False)
try:
    from tqdm import tqdm
    USE_TQDM = True
except Exception:
    tqdm = lambda x, **kwargs: x
    USE_TQDM = False

OLLAMA_URL = "http://127.0.0.1:11434"  # change if needed

# %%
def slugify(s: str) -> str:
    return re.sub(r'[^a-zA-Z0-9._-]+', '_', s).strip('_').lower()

def read_json_dataset(path: str) -> List[Dict[str, Any]]:
    """
    Reads either:
    - a JSON array of objects, or
    - a JSONL file (one JSON object per line)
    """
    p = Path(path)
    txt = p.read_text(encoding='utf-8')
    # Heuristic: if first non-space char is '[', treat as JSON array.
    first_non_ws = next((c for c in txt if not c.isspace()), '[')
    if first_non_ws == '[':
        data = json.loads(txt)
        assert isinstance(data, list), "Top-level JSON must be a list of objects."
        return data
    # Else fall back to JSONL
    records = []
    for line in txt.splitlines():
        line = line.strip()
        if line:
            records.append(json.loads(line))
    return records

def normalize_label(label: str) -> str:
    if label is None:
        return ""
    s = label.strip().lower()
    # Map various aliases to two classes
    if s in {"supported", "true", "yes", "accepted", "accurate", "correct"}:
        return "Supported"
    if s in {"refuted", "false", "no", "rejected", "inaccurate", "incorrect"}:
        return "Refuted"
    # If unknown, return capitalized original
    return label.capitalize()

def ensure_fields(obj: Dict[str, Any], required=("claim","label","justification")):
    for k in required:
        if k not in obj:
            raise ValueError(f"Dataset record missing required field: {k}")

# %%
import subprocess, json, re

INSTRUCTION = (
    "You are a fact-checking assistant.\n"
    "Return ONLY a JSON object with these exact fields:\n"
    '  \"label\": one of [\"Supported\", \"Refuted\"],\n'
    '  \"justification\": a short, factual justification (1-3 sentences).\n'
    "Do not write anything before or after the JSON. Do not add any other keys."
)

def _extract_json_block(text: str):
    """Try to parse a JSON object from raw text (handles code fences, chatter)."""
    try:
        t = text.strip()
        if "```" in t:
            parts = t.split("```")
            t = max(parts, key=len)
        m = re.search(r"\{[\s\S]*\}", t)
        if m:
            return json.loads(m.group(0))
        return json.loads(t)
    except Exception:
        return None

def _exec(cmd, input_text=None, timeout=900):
    """Run a subprocess and capture output."""
    proc = subprocess.run(
        cmd,
        input=input_text,
        capture_output=True,
        text=True,
        timeout=timeout
    )
    return proc.returncode, (proc.stdout or ""), (proc.stderr or "")

def ask_ollama(model: str, claim: str, system: str = INSTRUCTION, timeout: int = 900):
    """
    Use `ollama run` with multiple fallback styles to support older CLIs.
    Returns: (raw_text, label_pred, justification_pred)
    """
    model = (model or "").strip()
    prompt_only = f"Claim: {claim}\nRespond with JSON as specified."
    system_plus_prompt = f"{system}\n\n{prompt_only}"

    errors = []

    # Attempt 1: ollama run --model <m> --system <sys> --prompt <p>
    cmd1 = ["ollama", "run", "--model", model, "--system", system, "--prompt", prompt_only]
    rc, out, err = _exec(cmd1, timeout=timeout)
    if rc == 0 and out.strip():
        j = _extract_json_block(out) or {}
        label_pred = normalize_label(j.get("label", ""))
        just_pred = (j.get("justification", "") or "").strip()
        return out, label_pred, just_pred
    errors.append((" ".join(cmd1), rc, err.strip()))

    # Attempt 2: ollama run <m> --system <sys> --prompt <p>
    cmd2 = ["ollama", "run", model, "--system", system, "--prompt", prompt_only]
    rc, out, err = _exec(cmd2, timeout=timeout)
    if rc == 0 and out.strip():
        j = _extract_json_block(out) or {}
        label_pred = normalize_label(j.get("label", ""))
        just_pred = (j.get("justification", "") or "").strip()
        return out, label_pred, just_pred
    errors.append((" ".join(cmd2), rc, err.strip()))

    # Attempt 3: ollama run <m> -p "<system + prompt>"
    cmd3 = ["ollama", "run", model, "-p", system_plus_prompt]
    rc, out, err = _exec(cmd3, timeout=timeout)
    if rc == 0 and out.strip():
        j = _extract_json_block(out) or {}
        label_pred = normalize_label(j.get("label", ""))
        just_pred = (j.get("justification", "") or "").strip()
        return out, label_pred, just_pred
    errors.append((" ".join(cmd3), rc, err.strip()))

    # Attempt 4: feed via stdin (some very old CLIs)
    cmd4 = ["ollama", "run", model]
    rc, out, err = _exec(cmd4, input_text=system_plus_prompt, timeout=timeout)
    if rc == 0 and out.strip():
        j = _extract_json_block(out) or {}
        label_pred = normalize_label(j.get("label", ""))
        just_pred = (j.get("justification", "") or "").strip()
        return out, label_pred, just_pred
    errors.append((" ".join(cmd4), rc, err.strip()))

    # If all failed, surface a helpful error
    err_msg = ["All ollama run attempts failed."]
    for cmd, code, e in errors:
        if e:
            err_msg.append(f"\n---\nCommand: {cmd}\nExit: {code}\nError:\n{e}")
    # Common hint
    err_msg.append(f"\nHint: ensure the model exists locally:\n  ollama pull {model}")
    raise RuntimeError("\n".join(err_msg))

# %%
def cosine_sbert(a: str, b: str, model_name: str = "sentence-transformers/all-MiniLM-L6-v2") -> Optional[float]:
    """
    SBERT cosine similarity. Returns None if sentence-transformers unavailable.
    """
    if SentenceTransformer is None:
        return None
    global _sbert_model
    try:
        _sbert_model
    except NameError:
        _sbert_model = SentenceTransformer(model_name)
    vecs = _sbert_model.encode([a, b], convert_to_numpy=True, normalize_embeddings=True)
    return float((vecs[0] * vecs[1]).sum())

def cosine_tfidf(a: str, b: str) -> float:
    vec = TfidfVectorizer().fit_transform([a, b])
    return float(cosine_similarity(vec[0], vec[1])[0,0])

def rougeL_f1(pred: str, ref: str) -> Optional[float]:
    if rouge_scorer is None:
        return None
    scorer = rouge_scorer.RougeScorer(['rougeL'], use_stemmer=True)
    scores = scorer.score(ref, pred)  # (reference, prediction)
    return float(scores['rougeL'].fmeasure)

def bleu_sentence(pred: str, ref: str) -> Optional[float]:
    if sacrebleu is None:
        return None
    # SacreBLEU expects list of references
    return float(sacrebleu.sentence_bleu(pred, [ref]).score)

def bertscore_f1(pred: str, ref: str, lang: str = "en") -> Optional[float]:
    if bertscore_score is None:
        return None
    import torch
    with torch.no_grad():
        P, R, F = bertscore_score([pred], [ref], lang=lang, rescale_with_baseline=True)
    return float(F.mean().item())

# %%
# ▶️ Configuration
DATASET_PATH = "data/refuted_claims.json"  # <-- set to your JSON file (array or JSONL)
MODEL = (MODEL or "").strip()         # e.g., "qwen3:4b", "mistral:7b", "gemma3:4b"
OUTDIR = "runs"
LANG = "en"                   # language code for BERTScore baseline rescaling

# %%
records = read_json_dataset(DATASET_PATH)

# Validate and normalize
clean = []
for r in records:
    ensure_fields(r, required=("claim","label","justification"))
    claim = str(r["claim"]).strip()
    label = normalize_label(str(r["label"]))
    just  = str(r["justification"]).strip()
    clean.append({"claim": claim, "label": label, "justification": just})

print(f"Loaded {len(clean)} records.")
if clean:
    print("Sample record:", clean[0])
# Out:
# Loaded 1742 records.
# Sample record: {'claim': 'Donald Trump delivered the largest tax cuts in American history.', 'label': 'Refuted', 'justification': 'Three tax bills have been larger than that of Donald Trump'}

# %%
rows = []
subset = clean[:100]  # Limit to first 100 rows
iterator = tqdm(subset, desc="Evaluating") if USE_TQDM else subset

for row in iterator:
    claim = row["claim"]
    gt_label = row["label"]
    gt_just = row["justification"]

    raw, label_pred, just_pred = ask_ollama(MODEL, claim)

    # Metrics: justification_pred vs ground-truth justification
    rouge = rougeL_f1(just_pred, gt_just)
    bleu = bleu_sentence(just_pred, gt_just)
    # Cosine: prefer SBERT, fallback to TF-IDF
    cos = cosine_sbert(just_pred, gt_just)
    if cos is None:
        cos = cosine_tfidf(just_pred, gt_just)
    bert_f1 = bertscore_f1(just_pred, gt_just, lang=LANG)

    rows.append({
        "claim": claim,
        "label": gt_label,
        "justification": gt_just,
        "label_pred": label_pred,
        "justification_pred": just_pred,
        "rougeL_f1": rouge,
        "bleu": bleu,
        "cosine": cos,
        "bertscore_f1": bert_f1,
    })

df = pd.DataFrame(rows)
df.head()
# Out:
# Evaluating:   0%|          | 0/100 [00:00<?, ?it/s]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   1%|          | 1/100 [00:24<40:30, 24.55s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   2%|▏         | 2/100 [00:28<20:07, 12.32s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   3%|▎         | 3/100 [00:31<13:23,  8.28s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   4%|▍         | 4/100 [00:35<10:22,  6.48s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   5%|▌         | 5/100 [00:39<08:39,  5.47s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   6%|▌         | 6/100 [00:42<07:34,  4.83s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   7%|▋         | 7/100 [00:46<06:54,  4.46s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   8%|▊         | 8/100 [00:50<06:39,  4.35s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   9%|▉         | 9/100 [00:54<06:21,  4.19s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  10%|█         | 10/100 [00:58<06:01,  4.01s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  11%|█         | 11/100 [01:02<05:56,  4.00s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  12%|█▏        | 12/100 [01:05<05:48,  3.96s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  13%|█▎        | 13/100 [01:09<05:38,  3.89s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  14%|█▍        | 14/100 [01:13<05:25,  3.79s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  15%|█▌        | 15/100 [01:16<05:21,  3.78s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  16%|█▌        | 16/100 [01:20<05:17,  3.78s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  17%|█▋        | 17/100 [01:24<05:15,  3.80s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  18%|█▊        | 18/100 [01:28<05:05,  3.72s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  19%|█▉        | 19/100 [01:32<05:07,  3.80s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  20%|██        | 20/100 [01:36<05:08,  3.85s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  21%|██        | 21/100 [01:39<04:59,  3.79s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  22%|██▏       | 22/100 [01:43<04:56,  3.80s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  23%|██▎       | 23/100 [01:47<04:48,  3.74s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  24%|██▍       | 24/100 [01:50<04:47,  3.78s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  25%|██▌       | 25/100 [01:55<04:50,  3.88s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  26%|██▌       | 26/100 [01:58<04:42,  3.82s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  27%|██▋       | 27/100 [02:02<04:42,  3.88s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  28%|██▊       | 28/100 [02:07<04:50,  4.03s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  29%|██▉       | 29/100 [02:11<04:46,  4.03s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  30%|███       | 30/100 [02:15<04:37,  3.97s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  31%|███       | 31/100 [02:19<04:38,  4.04s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  32%|███▏      | 32/100 [02:23<04:34,  4.04s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  33%|███▎      | 33/100 [02:27<04:26,  3.97s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  34%|███▍      | 34/100 [02:31<04:21,  3.97s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  35%|███▌      | 35/100 [02:34<04:12,  3.88s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  36%|███▌      | 36/100 [02:38<04:06,  3.85s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  37%|███▋      | 37/100 [02:42<04:00,  3.82s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  38%|███▊      | 38/100 [02:46<03:58,  3.84s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  39%|███▉      | 39/100 [02:49<03:53,  3.83s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  40%|████      | 40/100 [02:53<03:44,  3.74s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  41%|████      | 41/100 [02:57<03:37,  3.69s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  42%|████▏     | 42/100 [03:00<03:35,  3.71s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  43%|████▎     | 43/100 [03:04<03:39,  3.85s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  44%|████▍     | 44/100 [03:09<03:40,  3.94s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  45%|████▌     | 45/100 [03:12<03:33,  3.88s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  46%|████▌     | 46/100 [03:16<03:26,  3.82s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  47%|████▋     | 47/100 [03:19<03:14,  3.68s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  48%|████▊     | 48/100 [03:23<03:15,  3.76s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  49%|████▉     | 49/100 [03:27<03:17,  3.87s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  50%|█████     | 50/100 [03:31<03:14,  3.89s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  51%|█████     | 51/100 [03:36<03:15,  3.98s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  52%|█████▏    | 52/100 [03:40<03:10,  3.97s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  53%|█████▎    | 53/100 [03:44<03:06,  3.98s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  54%|█████▍    | 54/100 [03:47<02:57,  3.86s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  55%|█████▌    | 55/100 [03:51<03:00,  4.00s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  56%|█████▌    | 56/100 [03:55<02:51,  3.90s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  57%|█████▋    | 57/100 [04:00<02:55,  4.08s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  58%|█████▊    | 58/100 [04:04<02:49,  4.04s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  59%|█████▉    | 59/100 [04:08<02:44,  4.01s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  60%|██████    | 60/100 [04:11<02:39,  3.98s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  61%|██████    | 61/100 [04:15<02:32,  3.91s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  62%|██████▏   | 62/100 [04:19<02:26,  3.85s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  63%|██████▎   | 63/100 [04:22<02:18,  3.75s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  64%|██████▍   | 64/100 [04:26<02:15,  3.75s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  65%|██████▌   | 65/100 [04:30<02:11,  3.75s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  66%|██████▌   | 66/100 [04:35<02:24,  4.24s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  67%|██████▋   | 67/100 [04:40<02:21,  4.30s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  68%|██████▊   | 68/100 [04:45<02:22,  4.46s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  69%|██████▉   | 69/100 [04:49<02:16,  4.40s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  70%|███████   | 70/100 [04:53<02:06,  4.23s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  71%|███████   | 71/100 [04:58<02:08,  4.45s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  72%|███████▏  | 72/100 [05:01<01:59,  4.25s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  73%|███████▎  | 73/100 [05:05<01:49,  4.06s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  74%|███████▍  | 74/100 [05:09<01:47,  4.14s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  75%|███████▌  | 75/100 [05:13<01:41,  4.08s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  76%|███████▌  | 76/100 [05:18<01:42,  4.28s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  77%|███████▋  | 77/100 [05:22<01:36,  4.19s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  78%|███████▊  | 78/100 [05:26<01:31,  4.16s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  79%|███████▉  | 79/100 [05:30<01:26,  4.13s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  80%|████████  | 80/100 [05:35<01:24,  4.22s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  81%|████████  | 81/100 [05:38<01:16,  4.03s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  82%|████████▏ | 82/100 [05:42<01:13,  4.09s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  83%|████████▎ | 83/100 [05:46<01:07,  3.98s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  84%|████████▍ | 84/100 [05:50<01:03,  3.99s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  85%|████████▌ | 85/100 [05:54<01:00,  4.02s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  86%|████████▌ | 86/100 [05:58<00:55,  3.96s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  87%|████████▋ | 87/100 [06:02<00:50,  3.92s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  88%|████████▊ | 88/100 [06:06<00:47,  3.94s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  89%|████████▉ | 89/100 [06:10<00:43,  3.91s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  90%|█████████ | 90/100 [06:14<00:38,  3.89s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  91%|█████████ | 91/100 [06:17<00:35,  3.90s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  92%|█████████▏| 92/100 [06:21<00:31,  3.93s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  93%|█████████▎| 93/100 [06:25<00:27,  3.90s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  94%|█████████▍| 94/100 [06:29<00:23,  3.94s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  95%|█████████▌| 95/100 [06:33<00:20,  4.00s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  96%|█████████▌| 96/100 [06:37<00:15,  3.92s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  97%|█████████▋| 97/100 [06:41<00:11,  3.88s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  98%|█████████▊| 98/100 [06:45<00:07,  3.86s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  99%|█████████▉| 99/100 [06:49<00:03,  3.90s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating: 100%|██████████| 100/100 [06:53<00:00,  4.13s/it]
#                                                claim    label  \
# 0  Donald Trump delivered the largest tax cuts in...  Refuted
# 1  After the police shooting of Jacob Blake, Gov....  Refuted
# 2  The Common Law Admission Test (CLAT) 2020 will...  Refuted
# 3        35% of revenue goes to states. (In Nigeria)  Refuted
# 4         Biden will take away the Second Amendment.  Refuted
#
#                                        justification label_pred  \
# 0  Three tax bills have been larger than that of ...    Refuted
# 1  Governor Evers did call for peace in a video s...    Refuted
# 2  The answer and credible source show that the c...    Refuted
# 3  The answer shows that 26.72% goes to states so...    Refuted
# 4        Biden does not want to end second amendment    Refuted
#
#                                   justification_pred  rougeL_f1      bleu  \
# 0  While the Tax Cuts and Jobs Act of 2017 did si...   0.058824  0.721508
# 1  Immediately following the shooting of Jacob Bl...   0.203390  1.116927
# 2  The CLAT 2020 was indeed conducted on Septembe...   0.166667  1.604730
# 3  According to the Nigerian National Bureau of S...   0.150943  2.045903
# 4  President Biden has repeatedly stated his supp...   0.105263  0.867134
#
#      cosine  bertscore_f1
# 0  0.505651     -0.028562
# 1  0.663605      0.310760
# 2  0.111705      0.139139
# 3  0.465787      0.233251
# 4  0.668749      0.210925

# %%
outdir = Path(OUTDIR)
outdir.mkdir(parents=True, exist_ok=True)
out_csv = outdir / f"{slugify(MODEL)}_claim_eval.csv"
df.to_csv(out_csv, index=False, encoding="utf-8")
print(f"Saved: {out_csv.resolve()}")
# Out:
# Saved: C:\Users\edupa\Desktop\StateOfArt\StressTestingModels_StateOfArt\runs\gemma3_4b_claim_eval.csv

# %%
size = len(df)

# %%
size
# Out:
# 100

# %% [markdown]
# Mistral

# %%
# ▶️ Configuration
DATASET_PATH = "data/refuted_claims.json"  # <-- set to your JSON file (array or JSONL)
MODEL = ("mistral:7b").strip()         # e.g., "qwen3:4b", "mistral:7b", "gemma3:4b"
OUTDIR = "runs"
LANG = "en"                   # language code for BERTScore baseline rescaling

# %%
rows = []
subset = clean[:100]  # Limit to first 100 rows
iterator = tqdm(subset, desc="Evaluating") if USE_TQDM else subset

for row in iterator:
    claim = row["claim"]
    gt_label = row["label"]
    gt_just = row["justification"]

    raw, label_pred, just_pred = ask_ollama(MODEL, claim)

    # Metrics: justification_pred vs ground-truth justification
    rouge = rougeL_f1(just_pred, gt_just)
    bleu = bleu_sentence(just_pred, gt_just)
    # Cosine: prefer SBERT, fallback to TF-IDF
    cos = cosine_sbert(just_pred, gt_just)
    if cos is None:
        cos = cosine_tfidf(just_pred, gt_just)
    bert_f1 = bertscore_f1(just_pred, gt_just, lang=LANG)

    rows.append({
        "claim": claim,
        "label": gt_label,
        "justification": gt_just,
        "label_pred": label_pred,
        "justification_pred": just_pred,
        "rougeL_f1": rouge,
        "bleu": bleu,
        "cosine": cos,
        "bertscore_f1": bert_f1,
    })

df = pd.DataFrame(rows)
df.head()
# Out:
# Evaluating:   0%|          | 0/100 [00:00<?, ?it/s]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   1%|          | 1/100 [00:08<14:13,  8.63s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   2%|▏         | 2/100 [00:13<10:29,  6.43s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   3%|▎         | 3/100 [00:16<08:03,  4.99s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   4%|▍         | 4/100 [00:20<07:11,  4.50s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   5%|▌         | 5/100 [00:24<06:37,  4.19s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   6%|▌         | 6/100 [00:27<05:56,  3.80s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   7%|▋         | 7/100 [00:30<05:38,  3.64s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   8%|▊         | 8/100 [00:33<05:03,  3.30s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   9%|▉         | 9/100 [00:37<05:25,  3.58s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  10%|█         | 10/100 [00:40<05:08,  3.43s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  11%|█         | 11/100 [00:43<05:04,  3.42s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  12%|█▏        | 12/100 [00:46<04:53,  3.33s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  13%|█▎        | 13/100 [00:51<05:21,  3.69s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  14%|█▍        | 14/100 [00:55<05:36,  3.91s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  15%|█▌        | 15/100 [01:00<05:39,  3.99s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  16%|█▌        | 16/100 [01:03<05:24,  3.87s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  17%|█▋        | 17/100 [01:06<05:03,  3.66s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  18%|█▊        | 18/100 [01:09<04:43,  3.46s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  19%|█▉        | 19/100 [01:13<04:52,  3.61s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  20%|██        | 20/100 [01:16<04:39,  3.49s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  21%|██        | 21/100 [01:20<04:42,  3.58s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  22%|██▏       | 22/100 [01:24<04:42,  3.63s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  23%|██▎       | 23/100 [01:27<04:21,  3.39s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  24%|██▍       | 24/100 [01:31<04:25,  3.49s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  25%|██▌       | 25/100 [01:34<04:19,  3.46s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  26%|██▌       | 26/100 [01:38<04:33,  3.69s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  27%|██▋       | 27/100 [01:42<04:26,  3.65s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  28%|██▊       | 28/100 [01:45<04:14,  3.53s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  29%|██▉       | 29/100 [01:48<04:04,  3.44s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  30%|███       | 30/100 [01:51<03:49,  3.28s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  31%|███       | 31/100 [01:55<03:54,  3.39s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  32%|███▏      | 32/100 [01:59<04:15,  3.76s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  33%|███▎      | 33/100 [02:04<04:22,  3.92s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  34%|███▍      | 34/100 [02:08<04:17,  3.90s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  35%|███▌      | 35/100 [02:11<04:11,  3.87s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  36%|███▌      | 36/100 [02:15<04:04,  3.82s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  37%|███▋      | 37/100 [02:18<03:50,  3.66s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  38%|███▊      | 38/100 [02:22<03:38,  3.52s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Evaluating:  39%|███▉      | 39/100 [02:25<03:26,  3.38s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  40%|████      | 40/100 [02:27<03:11,  3.19s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  41%|████      | 41/100 [02:31<03:08,  3.19s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Evaluating:  42%|████▏     | 42/100 [02:34<03:11,  3.31s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  43%|████▎     | 43/100 [02:38<03:11,  3.36s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  44%|████▍     | 44/100 [02:41<03:12,  3.43s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  45%|████▌     | 45/100 [02:44<03:02,  3.32s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Evaluating:  46%|████▌     | 46/100 [02:48<03:00,  3.34s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Evaluating:  47%|████▋     | 47/100 [02:51<02:51,  3.23s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  48%|████▊     | 48/100 [02:55<03:11,  3.67s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  49%|████▉     | 49/100 [02:59<03:05,  3.64s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  50%|█████     | 50/100 [03:02<02:59,  3.59s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  51%|█████     | 51/100 [03:06<02:59,  3.65s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  52%|█████▏    | 52/100 [03:09<02:49,  3.53s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  53%|█████▎    | 53/100 [03:12<02:31,  3.23s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  54%|█████▍    | 54/100 [03:15<02:29,  3.26s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  55%|█████▌    | 55/100 [03:23<03:29,  4.65s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  56%|█████▌    | 56/100 [03:27<03:14,  4.42s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  57%|█████▋    | 57/100 [03:30<02:54,  4.06s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  58%|█████▊    | 58/100 [03:34<02:42,  3.86s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  59%|█████▉    | 59/100 [03:37<02:29,  3.66s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Evaluating:  60%|██████    | 60/100 [03:40<02:24,  3.61s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  61%|██████    | 61/100 [03:45<02:32,  3.91s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  62%|██████▏   | 62/100 [03:48<02:18,  3.65s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  63%|██████▎   | 63/100 [03:52<02:16,  3.69s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  64%|██████▍   | 64/100 [03:55<02:05,  3.48s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  65%|██████▌   | 65/100 [03:58<01:55,  3.31s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  66%|██████▌   | 66/100 [04:02<02:01,  3.58s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  67%|██████▋   | 67/100 [04:06<02:01,  3.68s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  68%|██████▊   | 68/100 [04:09<01:56,  3.63s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  69%|██████▉   | 69/100 [04:13<01:51,  3.58s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  70%|███████   | 70/100 [04:16<01:46,  3.53s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  71%|███████   | 71/100 [04:19<01:40,  3.46s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  72%|███████▏  | 72/100 [04:24<01:45,  3.76s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  73%|███████▎  | 73/100 [04:27<01:38,  3.66s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  74%|███████▍  | 74/100 [04:30<01:29,  3.42s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  75%|███████▌  | 75/100 [04:34<01:28,  3.52s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  76%|███████▌  | 76/100 [04:38<01:28,  3.68s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  77%|███████▋  | 77/100 [04:42<01:23,  3.62s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  78%|███████▊  | 78/100 [04:45<01:17,  3.52s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  79%|███████▉  | 79/100 [04:48<01:13,  3.49s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  80%|████████  | 80/100 [04:51<01:08,  3.42s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  81%|████████  | 81/100 [04:54<01:02,  3.29s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  82%|████████▏ | 82/100 [04:58<00:59,  3.30s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  83%|████████▎ | 83/100 [05:02<00:58,  3.44s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  84%|████████▍ | 84/100 [05:05<00:54,  3.38s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  85%|████████▌ | 85/100 [05:09<00:54,  3.62s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  86%|████████▌ | 86/100 [05:13<00:51,  3.70s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  87%|████████▋ | 87/100 [05:16<00:46,  3.61s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  88%|████████▊ | 88/100 [05:20<00:45,  3.77s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  89%|████████▉ | 89/100 [05:24<00:41,  3.75s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  90%|█████████ | 90/100 [05:27<00:35,  3.52s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  91%|█████████ | 91/100 [05:31<00:33,  3.74s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  92%|█████████▏| 92/100 [05:35<00:30,  3.80s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  93%|█████████▎| 93/100 [05:39<00:25,  3.65s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  94%|█████████▍| 94/100 [05:43<00:22,  3.80s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  95%|█████████▌| 95/100 [05:47<00:19,  3.81s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  96%|█████████▌| 96/100 [05:51<00:15,  3.89s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  97%|█████████▋| 97/100 [05:53<00:10,  3.55s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  98%|█████████▊| 98/100 [05:56<00:06,  3.36s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  99%|█████████▉| 99/100 [06:00<00:03,  3.55s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Evaluating: 100%|██████████| 100/100 [06:04<00:00,  3.64s/it]
#                                                claim    label  \
# 0  Donald Trump delivered the largest tax cuts in...  Refuted
# 1  After the police shooting of Jacob Blake, Gov....  Refuted
# 2  The Common Law Admission Test (CLAT) 2020 will...  Refuted
# 3        35% of revenue goes to states. (In Nigeria)  Refuted
# 4         Biden will take away the Second Amendment.  Refuted
#
#                                        justification label_pred  \
# 0  Three tax bills have been larger than that of ...    Refuted
# 1  Governor Evers did call for peace in a video s...    Refuted
# 2  The answer and credible source show that the c...    Refuted
# 3  The answer shows that 26.72% goes to states so...    Refuted
# 4        Biden does not want to end second amendment    Refuted
#
#                                   justification_pred  rougeL_f1      bleu  \
# 0  The Tax Cuts and Jobs Act of 2017 signed by Pr...   0.115385  1.070014
# 1  Governor Tony Evers and Lt. Governor Mandela B...   0.300000  2.425832
# 2  The CLAT 2020 was indeed held on September 7, ...   0.171429  2.707658
# 3  According to the Nigerian National Bureau of S...   0.204082  1.401425
# 4  President Joe Biden has stated that he does no...   0.325581  6.787182
#
#      cosine  bertscore_f1
# 0  0.598126      0.073223
# 1  0.609289      0.310596
# 2  0.179843      0.155933
# 3  0.218446      0.165881
# 4  0.762660      0.342114

# %%
outdir = Path(OUTDIR)
outdir.mkdir(parents=True, exist_ok=True)
out_csv = outdir / f"{slugify(MODEL)}_claim_eval.csv"
df.to_csv(out_csv, index=False, encoding="utf-8")
print(f"Saved: {out_csv.resolve()}")
# Out:
# Saved: C:\Users\edupa\Desktop\StateOfArt\StressTestingModels_StateOfArt\runs\mistral_7b_claim_eval.csv
