# %% [markdown]
# # Claim Verification with Ollama + Justification Metrics
#
# This notebook:
# 1. Reads a **JSON** dataset of claims with `claim`, `label`, `justification`.
# 2. Calls a local **Ollama** model to predict a **label** (Supported/Refuted) **and** a **justification**.
# 3. Computes **ROUGE-L F1**, **BLEU**, **cosine similarity** (SBERT; fallback TF-IDF), and **BERTScore-F1** between model justification and ground-truth justification.
# 4. Produces a DataFrame with columns:
#    - `claim`, `label`, `justification`
#    - `label_pred`, `justification_pred`
#    - `rougeL_f1`, `bleu`, `cosine`, `bertscore_f1`
# 5. Saves results to `runs/<model_slug>_claim_eval.csv`.

# %%
# !pip install jupyter ipykernel requests pandas tqdm  rouge-score sacrebleu bert-score
# Out:
# Requirement already satisfied: jupyter in c:\users\edupa\miniforge3\lib\site-packages (1.1.1)
# Requirement already satisfied: ipykernel in c:\users\edupa\miniforge3\lib\site-packages (6.30.1)
# Requirement already satisfied: requests in c:\users\edupa\miniforge3\lib\site-packages (2.32.3)
# Requirement already satisfied: pandas in c:\users\edupa\miniforge3\lib\site-packages (2.2.3)
# Requirement already satisfied: tqdm in c:\users\edupa\miniforge3\lib\site-packages (4.67.1)
# Requirement already satisfied: rouge-score in c:\users\edupa\miniforge3\lib\site-packages (0.1.2)
# Requirement already satisfied: sacrebleu in c:\users\edupa\miniforge3\lib\site-packages (2.5.1)
# Requirement already satisfied: bert-score in c:\users\edupa\miniforge3\lib\site-packages (0.3.13)
# Requirement already satisfied: notebook in c:\users\edupa\miniforge3\lib\site-packages (from jupyter) (7.4.5)
# Requirement already satisfied: jupyter-console in c:\users\edupa\miniforge3\lib\site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\edupa\miniforge3\lib\site-packages (from jupyter) (7.16.6)
# Requirement already satisfied: ipywidgets in c:\users\edupa\miniforge3\lib\site-packages (from jupyter) (8.1.7)
# Requirement already satisfied: jupyterlab in c:\users\edupa\miniforge3\lib\site-packages (from jupyter) (4.4.7)
# Requirement already satisfied: comm>=0.1.1 in c:\users\edupa\miniforge3\lib\site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\edupa\miniforge3\lib\site-packages (from ipykernel) (1.8.17)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\edupa\miniforge3\lib\site-packages (from ipykernel) (8.12.3)
# Requirement already satisfied: jupyter-client>=8.0.0 in c:\users\edupa\miniforge3\lib\site-packages (from ipykernel) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\edupa\miniforge3\lib\site-packages (from ipykernel) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\edupa\miniforge3\lib\site-packages (from ipykernel) (0.1.7)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\edupa\miniforge3\lib\site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging>=22 in c:\users\edupa\miniforge3\lib\site-packages (from ipykernel) (24.2)
# Requirement already satisfied: psutil>=5.7 in c:\users\edupa\miniforge3\lib\site-packages (from ipykernel) (7.1.0)
# Requirement already satisfied: pyzmq>=25 in c:\users\edupa\miniforge3\lib\site-packages (from ipykernel) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in c:\users\edupa\miniforge3\lib\site-packages (from ipykernel) (6.5.2)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\edupa\miniforge3\lib\site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\edupa\miniforge3\lib\site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\edupa\miniforge3\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\edupa\miniforge3\lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\edupa\miniforge3\lib\site-packages (from requests) (2025.8.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\edupa\miniforge3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\edupa\miniforge3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\edupa\miniforge3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\edupa\miniforge3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: colorama in c:\users\edupa\miniforge3\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: absl-py in c:\users\edupa\miniforge3\lib\site-packages (from rouge-score) (2.3.1)
# Requirement already satisfied: nltk in c:\users\edupa\miniforge3\lib\site-packages (from rouge-score) (3.9.1)
# Requirement already satisfied: six>=1.14.0 in c:\users\edupa\miniforge3\lib\site-packages (from rouge-score) (1.17.0)
# Requirement already satisfied: portalocker in c:\users\edupa\miniforge3\lib\site-packages (from sacrebleu) (3.2.0)
# Requirement already satisfied: regex in c:\users\edupa\miniforge3\lib\site-packages (from sacrebleu) (2025.9.18)
# Requirement already satisfied: tabulate>=0.8.9 in c:\users\edupa\miniforge3\lib\site-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: lxml in c:\users\edupa\miniforge3\lib\site-packages (from sacrebleu) (6.0.2)
# Requirement already satisfied: torch>=1.0.0 in c:\users\edupa\miniforge3\lib\site-packages (from bert-score) (2.7.0)
# Requirement already satisfied: transformers>=3.0.0 in c:\users\edupa\miniforge3\lib\site-packages (from bert-score) (4.56.2)
# Requirement already satisfied: matplotlib in c:\users\edupa\miniforge3\lib\site-packages (from bert-score) (3.10.3)
# Requirement already satisfied: backcall in c:\users\edupa\miniforge3\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.2.0)
# Requirement already satisfied: decorator in c:\users\edupa\miniforge3\lib\site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\edupa\miniforge3\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: pickleshare in c:\users\edupa\miniforge3\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\edupa\miniforge3\lib\site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\edupa\miniforge3\lib\site-packages (from ipython>=7.23.1->ipykernel) (2.19.2)
# Requirement already satisfied: stack-data in c:\users\edupa\miniforge3\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\edupa\miniforge3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\edupa\miniforge3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (311)
# Requirement already satisfied: filelock in c:\users\edupa\miniforge3\lib\site-packages (from torch>=1.0.0->bert-score) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\edupa\miniforge3\lib\site-packages (from torch>=1.0.0->bert-score) (4.13.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\edupa\miniforge3\lib\site-packages (from torch>=1.0.0->bert-score) (1.14.0)
# Requirement already satisfied: networkx in c:\users\edupa\miniforge3\lib\site-packages (from torch>=1.0.0->bert-score) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\edupa\miniforge3\lib\site-packages (from torch>=1.0.0->bert-score) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\edupa\miniforge3\lib\site-packages (from torch>=1.0.0->bert-score) (2025.5.1)
# Requirement already satisfied: setuptools in c:\users\edupa\miniforge3\lib\site-packages (from torch>=1.0.0->bert-score) (75.8.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in c:\users\edupa\miniforge3\lib\site-packages (from transformers>=3.0.0->bert-score) (0.35.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\edupa\miniforge3\lib\site-packages (from transformers>=3.0.0->bert-score) (6.0.2)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\edupa\miniforge3\lib\site-packages (from transformers>=3.0.0->bert-score) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\edupa\miniforge3\lib\site-packages (from transformers>=3.0.0->bert-score) (0.6.2)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\edupa\miniforge3\lib\site-packages (from ipywidgets->jupyter) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\edupa\miniforge3\lib\site-packages (from ipywidgets->jupyter) (3.0.15)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\edupa\miniforge3\lib\site-packages (from jupyterlab->jupyter) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\edupa\miniforge3\lib\site-packages (from jupyterlab->jupyter) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\edupa\miniforge3\lib\site-packages (from jupyterlab->jupyter) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\edupa\miniforge3\lib\site-packages (from jupyterlab->jupyter) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\edupa\miniforge3\lib\site-packages (from jupyterlab->jupyter) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\edupa\miniforge3\lib\site-packages (from jupyterlab->jupyter) (0.2.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\edupa\miniforge3\lib\site-packages (from matplotlib->bert-score) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\edupa\miniforge3\lib\site-packages (from matplotlib->bert-score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\edupa\miniforge3\lib\site-packages (from matplotlib->bert-score) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\edupa\miniforge3\lib\site-packages (from matplotlib->bert-score) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\users\edupa\miniforge3\lib\site-packages (from matplotlib->bert-score) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\edupa\miniforge3\lib\site-packages (from matplotlib->bert-score) (3.2.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\edupa\miniforge3\lib\site-packages (from nbconvert->jupyter) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\edupa\miniforge3\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\edupa\miniforge3\lib\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\edupa\miniforge3\lib\site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\edupa\miniforge3\lib\site-packages (from nbconvert->jupyter) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\edupa\miniforge3\lib\site-packages (from nbconvert->jupyter) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\edupa\miniforge3\lib\site-packages (from nbconvert->jupyter) (0.10.2)
# Requirement already satisfied: nbformat>=5.7 in c:\users\edupa\miniforge3\lib\site-packages (from nbconvert->jupyter) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\edupa\miniforge3\lib\site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: click in c:\users\edupa\miniforge3\lib\site-packages (from nltk->rouge-score) (8.1.8)
# Requirement already satisfied: joblib in c:\users\edupa\miniforge3\lib\site-packages (from nltk->rouge-score) (1.5.2)
# Requirement already satisfied: webencodings in c:\users\edupa\miniforge3\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\edupa\miniforge3\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (1.4.0)
# Requirement already satisfied: anyio in c:\users\edupa\miniforge3\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (4.11.0)
# Requirement already satisfied: httpcore==1.* in c:\users\edupa\miniforge3\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\edupa\miniforge3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter) (0.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\edupa\miniforge3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.5)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\edupa\miniforge3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\edupa\miniforge3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\edupa\miniforge3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.5.3)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\edupa\miniforge3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.23.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\edupa\miniforge3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0.0)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\edupa\miniforge3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\edupa\miniforge3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\edupa\miniforge3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\users\edupa\miniforge3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\edupa\miniforge3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\edupa\miniforge3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (4.25.1)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\edupa\miniforge3\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter) (2.21.2)
# Requirement already satisfied: wcwidth in c:\users\edupa\miniforge3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel) (0.2.14)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\edupa\miniforge3\lib\site-packages (from sympy>=1.13.3->torch>=1.0.0->bert-score) (1.3.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\edupa\miniforge3\lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.8)
# Requirement already satisfied: executing>=1.2.0 in c:\users\edupa\miniforge3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\edupa\miniforge3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (3.0.0)
# Requirement already satisfied: pure_eval in c:\users\edupa\miniforge3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (0.2.3)
# Requirement already satisfied: sniffio>=1.1 in c:\users\edupa\miniforge3\lib\site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab->jupyter) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\edupa\miniforge3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\edupa\miniforge3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\edupa\miniforge3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\edupa\miniforge3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\edupa\miniforge3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.27.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\edupa\miniforge3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.3.0)
# Requirement already satisfied: rfc3339-validator in c:\users\edupa\miniforge3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\edupa\miniforge3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\edupa\miniforge3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\edupa\miniforge3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\edupa\miniforge3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in c:\users\edupa\miniforge3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.1.0)
# Requirement already satisfied: uri-template in c:\users\edupa\miniforge3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\edupa\miniforge3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\edupa\miniforge3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\edupa\miniforge3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.22)
# Requirement already satisfied: lark>=1.2.2 in c:\users\edupa\miniforge3\lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\edupa\miniforge3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\edupa\miniforge3\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.9.0.20250822)

# %%
# !pip install sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\edupa\miniforge3\lib\site-packages (5.1.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\edupa\miniforge3\lib\site-packages (from sentence-transformers) (4.56.2)
# Requirement already satisfied: tqdm in c:\users\edupa\miniforge3\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\edupa\miniforge3\lib\site-packages (from sentence-transformers) (2.7.0)
# Requirement already satisfied: scikit-learn in c:\users\edupa\miniforge3\lib\site-packages (from sentence-transformers) (1.7.2)
# Requirement already satisfied: scipy in c:\users\edupa\miniforge3\lib\site-packages (from sentence-transformers) (1.16.2)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\edupa\miniforge3\lib\site-packages (from sentence-transformers) (0.35.1)
# Requirement already satisfied: Pillow in c:\users\edupa\miniforge3\lib\site-packages (from sentence-transformers) (11.2.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\edupa\miniforge3\lib\site-packages (from sentence-transformers) (4.13.2)
# Requirement already satisfied: filelock in c:\users\edupa\miniforge3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\edupa\miniforge3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.5.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\edupa\miniforge3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\edupa\miniforge3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in c:\users\edupa\miniforge3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\edupa\miniforge3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx in c:\users\edupa\miniforge3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\edupa\miniforge3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\edupa\miniforge3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (75.8.2)
# Requirement already satisfied: colorama in c:\users\edupa\miniforge3\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: numpy>=1.17 in c:\users\edupa\miniforge3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\edupa\miniforge3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.9.18)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\edupa\miniforge3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\edupa\miniforge3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\edupa\miniforge3\lib\site-packages (from scikit-learn->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\edupa\miniforge3\lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\edupa\miniforge3\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\edupa\miniforge3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\edupa\miniforge3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\edupa\miniforge3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\edupa\miniforge3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\edupa\miniforge3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.8.3)

# %%
DATASET_PATH = "refuted_claims.json"   # your file
MODEL = "gemma3:4b "          # or qwen3:4b / mistral:7b / gemma3:4b
LANG = "en"                    # for BERTScore baseline rescaling

# %%
from pathlib import Path
import json, re, time
from typing import Dict, Any, List, Tuple, Optional

import pandas as pd
import numpy as np

# HTTP (Ollama)
try:
    import requests
except Exception:
    requests = None
import urllib.request, urllib.error

# Metrics
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer  # fallback if SBERT unavailable

# Optional libraries (guarded imports)
try:
    from sentence_transformers import SentenceTransformer
except Exception:
    SentenceTransformer = None

try:
    from bert_score import score as bertscore_score
except Exception:
    bertscore_score = None

try:
    import sacrebleu
except Exception:
    sacrebleu = None

try:
    from rouge_score import rouge_scorer
except Exception:
    rouge_scorer = None

# Optional progress bar (if not installed, you can set USE_TQDM=False)
try:
    from tqdm import tqdm
    USE_TQDM = True
except Exception:
    tqdm = lambda x, **kwargs: x
    USE_TQDM = False

OLLAMA_URL = "http://127.0.0.1:11434"  # change if needed

# %%
def slugify(s: str) -> str:
    return re.sub(r'[^a-zA-Z0-9._-]+', '_', s).strip('_').lower()

def read_json_dataset(path: str) -> List[Dict[str, Any]]:
    """
    Reads either:
    - a JSON array of objects, or
    - a JSONL file (one JSON object per line)
    """
    p = Path(path)
    txt = p.read_text(encoding='utf-8')
    # Heuristic: if first non-space char is '[', treat as JSON array.
    first_non_ws = next((c for c in txt if not c.isspace()), '[')
    if first_non_ws == '[':
        data = json.loads(txt)
        assert isinstance(data, list), "Top-level JSON must be a list of objects."
        return data
    # Else fall back to JSONL
    records = []
    for line in txt.splitlines():
        line = line.strip()
        if line:
            records.append(json.loads(line))
    return records

def normalize_label(label: str) -> str:
    if label is None:
        return ""
    s = label.strip().lower()
    # Map various aliases to two classes
    if s in {"supported", "true", "yes", "accepted", "accurate", "correct"}:
        return "Supported"
    if s in {"refuted", "false", "no", "rejected", "inaccurate", "incorrect"}:
        return "Refuted"
    # If unknown, return capitalized original
    return label.capitalize()

def ensure_fields(obj: Dict[str, Any], required=("claim","label","justification")):
    for k in required:
        if k not in obj:
            raise ValueError(f"Dataset record missing required field: {k}")

# %%
import subprocess, json, re

INSTRUCTION = (
    "You are a fact-checking assistant.\n"
    "Return ONLY a JSON object with these exact fields:\n"
    '  \"label\": one of [\"Supported\", \"Refuted\"],\n'
    '  \"justification\": a short, factual justification (1-3 sentences).\n'
    "Do not write anything before or after the JSON. Do not add any other keys."
)

def _extract_json_block(text: str):
    """Try to parse a JSON object from raw text (handles code fences, chatter)."""
    try:
        t = text.strip()
        if "```" in t:
            parts = t.split("```")
            t = max(parts, key=len)
        m = re.search(r"\{[\s\S]*\}", t)
        if m:
            return json.loads(m.group(0))
        return json.loads(t)
    except Exception:
        return None

def _exec(cmd, input_text=None, timeout=9000):
    """Run a subprocess and capture output."""
    proc = subprocess.run(
        cmd,
        input=input_text,
        capture_output=True,
        text=True,
        timeout=timeout
    )
    return proc.returncode, (proc.stdout or ""), (proc.stderr or "")

def ask_ollama(model: str, claim: str, system: str = INSTRUCTION, timeout: int = 9000):
    """
    Use `ollama run` with multiple fallback styles to support older CLIs.
    Returns: (raw_text, label_pred, justification_pred)
    """
    model = (model or "").strip()
    prompt_only = f"Claim: {claim}\nRespond with JSON as specified."
    system_plus_prompt = f"{system}\n\n{prompt_only}"

    errors = []

    # Attempt 1: ollama run --model <m> --system <sys> --prompt <p>
    cmd1 = ["ollama", "run", "--model", model, "--system", system, "--prompt", prompt_only]
    rc, out, err = _exec(cmd1, timeout=timeout)
    if rc == 0 and out.strip():
        j = _extract_json_block(out) or {}
        label_pred = normalize_label(j.get("label", ""))
        just_pred = (j.get("justification", "") or "").strip()
        return out, label_pred, just_pred
    errors.append((" ".join(cmd1), rc, err.strip()))

    # Attempt 2: ollama run <m> --system <sys> --prompt <p>
    cmd2 = ["ollama", "run", model, "--system", system, "--prompt", prompt_only]
    rc, out, err = _exec(cmd2, timeout=timeout)
    if rc == 0 and out.strip():
        j = _extract_json_block(out) or {}
        label_pred = normalize_label(j.get("label", ""))
        just_pred = (j.get("justification", "") or "").strip()
        return out, label_pred, just_pred
    errors.append((" ".join(cmd2), rc, err.strip()))

    # Attempt 3: ollama run <m> -p "<system + prompt>"
    cmd3 = ["ollama", "run", model, "-p", system_plus_prompt]
    rc, out, err = _exec(cmd3, timeout=timeout)
    if rc == 0 and out.strip():
        j = _extract_json_block(out) or {}
        label_pred = normalize_label(j.get("label", ""))
        just_pred = (j.get("justification", "") or "").strip()
        return out, label_pred, just_pred
    errors.append((" ".join(cmd3), rc, err.strip()))

    # Attempt 4: feed via stdin (some very old CLIs)
    cmd4 = ["ollama", "run", model]
    rc, out, err = _exec(cmd4, input_text=system_plus_prompt, timeout=timeout)
    if rc == 0 and out.strip():
        j = _extract_json_block(out) or {}
        label_pred = normalize_label(j.get("label", ""))
        just_pred = (j.get("justification", "") or "").strip()
        return out, label_pred, just_pred
    errors.append((" ".join(cmd4), rc, err.strip()))

    # If all failed, surface a helpful error
    err_msg = ["All ollama run attempts failed."]
    for cmd, code, e in errors:
        if e:
            err_msg.append(f"\n---\nCommand: {cmd}\nExit: {code}\nError:\n{e}")
    # Common hint
    err_msg.append(f"\nHint: ensure the model exists locally:\n  ollama pull {model}")
    raise RuntimeError("\n".join(err_msg))

# %%
def cosine_sbert(a: str, b: str, model_name: str = "sentence-transformers/all-MiniLM-L6-v2") -> Optional[float]:
    """
    SBERT cosine similarity. Returns None if sentence-transformers unavailable.
    """
    if SentenceTransformer is None:
        return None
    global _sbert_model
    try:
        _sbert_model
    except NameError:
        _sbert_model = SentenceTransformer(model_name)
    vecs = _sbert_model.encode([a, b], convert_to_numpy=True, normalize_embeddings=True)
    return float((vecs[0] * vecs[1]).sum())

def cosine_tfidf(a: str, b: str) -> float:
    vec = TfidfVectorizer().fit_transform([a, b])
    return float(cosine_similarity(vec[0], vec[1])[0,0])

def rougeL_f1(pred: str, ref: str) -> Optional[float]:
    if rouge_scorer is None:
        return None
    scorer = rouge_scorer.RougeScorer(['rougeL'], use_stemmer=True)
    scores = scorer.score(ref, pred)  # (reference, prediction)
    return float(scores['rougeL'].fmeasure)

def bleu_sentence(pred: str, ref: str) -> Optional[float]:
    if sacrebleu is None:
        return None
    # SacreBLEU expects list of references
    return float(sacrebleu.sentence_bleu(pred, [ref]).score)

def bertscore_f1(pred: str, ref: str, lang: str = "en") -> Optional[float]:
    if bertscore_score is None:
        return None
    import torch
    with torch.no_grad():
        P, R, F = bertscore_score([pred], [ref], lang=lang, rescale_with_baseline=True)
    return float(F.mean().item())

# %%
# ▶️ Configuration
DATASET_PATH = "data/refuted_claims.json"  # <-- set to your JSON file (array or JSONL)
MODEL = (MODEL or "").strip()         # e.g., "qwen3:4b", "mistral:7b", "gemma3:4b"
OUTDIR = "runs"
LANG = "en"                   # language code for BERTScore baseline rescaling

# %%
records = read_json_dataset(DATASET_PATH)

# Validate and normalize
clean = []
for r in records:
    ensure_fields(r, required=("claim","label","justification"))
    claim = str(r["claim"]).strip()
    label = normalize_label(str(r["label"]))
    just  = str(r["justification"]).strip()
    clean.append({"claim": claim, "label": label, "justification": just})

print(f"Loaded {len(clean)} records.")
if clean:
    print("Sample record:", clean[0])
# Out:
# Loaded 1742 records.
# Sample record: {'claim': 'Donald Trump delivered the largest tax cuts in American history.', 'label': 'Refuted', 'justification': 'Three tax bills have been larger than that of Donald Trump'}

# %%
outdir = Path(OUTDIR)
outdir.mkdir(parents=True, exist_ok=True)
out_csv = outdir / f"{slugify(MODEL)}_claim_eval.csv"
df.to_csv(out_csv, index=False, encoding="utf-8")
print(f"Saved: {out_csv.resolve()}")
# Out:
# Saved: C:\Users\edupa\Desktop\StateOfArt\StressTestingModels_StateOfArt\runs\gemma3_4b_claim_eval.csv

# %%
size = len(df)

# %%
size
# Out:
# 100

# %% [markdown]
# Mistral

# %%
# ▶️ Configuration
DATASET_PATH = "data/refuted_claims.json"  # <-- set to your JSON file (array or JSONL)
MODEL = ("mistral:7b").strip()         # e.g., "qwen3:4b", "mistral:7b", "gemma3:4b"
OUTDIR = "runs"
LANG = "en"                   # language code for BERTScore baseline rescaling

# %%
# """"
# Test script for mistral for 100 row

# rows = []
# subset = clean[:1742]  # Limit to first 100 rows
# iterator = tqdm(subset, desc="Evaluating") if USE_TQDM else subset

# for row in iterator:
#     claim = row["claim"]
#     gt_label = row["label"]
#     gt_just = row["justification"]

#     raw, label_pred, just_pred = ask_ollama(MODEL, claim)

#     # Metrics: justification_pred vs ground-truth justification
#     rouge = rougeL_f1(just_pred, gt_just)
#     bleu = bleu_sentence(just_pred, gt_just)
#     # Cosine: prefer SBERT, fallback to TF-IDF
#     cos = cosine_sbert(just_pred, gt_just)
#     if cos is None:
#         cos = cosine_tfidf(just_pred, gt_just)
#     bert_f1 = bertscore_f1(just_pred, gt_just, lang=LANG)

#     rows.append({
#         "claim": claim,
#         "label": gt_label,
#         "justification": gt_just,
#         "label_pred": label_pred,
#         "justification_pred": just_pred,
#         "rougeL_f1": rouge,
#         "bleu": bleu,
#         "cosine": cos,
#         "bertscore_f1": bert_f1,
#     })

# df = pd.DataFrame(rows)
# df.head()
# """"

# %%
#outdir = Path(OUTDIR)
#outdir.mkdir(parents=True, exist_ok=True)
#out_csv = outdir / f"{slugify(MODEL)}_claim_eval.csv"
#df.to_csv(out_csv, index=False, encoding="utf-8")
#print(f"Saved: {out_csv.resolve()}")

# %% [markdown]
# Fixe the TimeOut problem

# %%
DATASET_PATH = "data/refuted_claims.json"  # <-- set to your JSON file (array or JSONL)
MODEL = (MODEL or "").strip()         # e.g., "qwen3:4b", "mistral:7b", "gemma3:4b"
OUTDIR = "runs"
LANG = "en"                   # language code for BERTScore baseline rescaling

# %%
import pandas as pd
import concurrent.futures
from tqdm import tqdm

# --- CONFIG ---
MAX_WORKERS = 4          # number of parallel threads
MODEL_TIMEOUT = 300      # seconds per model call
EVAL_LIMIT = 500         # number of rows to evaluate

subset = clean[:EVAL_LIMIT]
rows = []

# --- Safe model call wrapper ---
def safe_ask_ollama(row):
    claim = row["claim"]
    gt_label = row["label"]
    gt_just = row["justification"]

    try:
        raw, label_pred, just_pred = ask_ollama(MODEL, claim)
        if not just_pred:
            raise ValueError("Empty justification")

        # Metrics
        rouge = rougeL_f1(just_pred, gt_just)
        bleu = bleu_sentence(just_pred, gt_just)
        cos = cosine_sbert(just_pred, gt_just)
        if cos is None:
            cos = cosine_tfidf(just_pred, gt_just)
        bert_f1 = bertscore_f1(just_pred, gt_just, lang=LANG)

        return {
            "claim": claim,
            "label": gt_label,
            "justification": gt_just,
            "label_pred": label_pred,
            "justification_pred": just_pred,
            "rougeL_f1": rouge,
            "bleu": bleu,
            "cosine": cos,
            "bertscore_f1": bert_f1,
        }

    except Exception as e:
        return {
            "claim": claim,
            "label": gt_label,
            "error": str(e),
        }


# --- Parallel Execution with Timeout ---
results = []
with concurrent.futures.ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
    futures = {executor.submit(safe_ask_ollama, row): row for row in subset}
    for future in tqdm(concurrent.futures.as_completed(futures), total=len(futures), desc="Evaluating"):
        try:
            result = future.result(timeout=MODEL_TIMEOUT)
            results.append(result)
        except concurrent.futures.TimeoutError:
            claim = futures[future]["claim"]
            print(f"⚠️ Timeout for claim: {claim[:60]}...")
            results.append({
                "claim": claim,
                "error": "Timeout"
            })

# --- Combine results ---
df = pd.DataFrame(results)

# --- Save to CSV for safety ---
df.to_csv("ollama_eval_results.csv", index=False)

print("✅ Evaluation completed!")
df.head()
# Out:
# Evaluating:   0%|          | 0/500 [00:00<?, ?it/s]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   0%|          | 1/500 [00:08<1:08:54,  8.28s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   0%|          | 2/500 [00:09<36:38,  4.41s/it]  Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   1%|          | 3/500 [00:11<26:47,  3.23s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   1%|          | 4/500 [00:13<21:32,  2.61s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   1%|          | 5/500 [00:14<18:06,  2.20s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   1%|          | 6/500 [00:16<15:35,  1.89s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   1%|▏         | 7/500 [00:17<15:11,  1.85s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   2%|▏         | 8/500 [00:19<13:52,  1.69s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   2%|▏         | 9/500 [00:21<15:03,  1.84s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   2%|▏         | 10/500 [00:23<14:33,  1.78s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   2%|▏         | 11/500 [00:24<12:52,  1.58s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   2%|▏         | 12/500 [00:26<13:26,  1.65s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   3%|▎         | 13/500 [00:28<14:35,  1.80s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   3%|▎         | 14/500 [00:29<13:22,  1.65s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   3%|▎         | 15/500 [00:31<13:13,  1.64s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   3%|▎         | 16/500 [00:32<13:39,  1.69s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   3%|▎         | 17/500 [00:34<13:15,  1.65s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   4%|▎         | 18/500 [00:36<13:15,  1.65s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   4%|▍         | 19/500 [00:37<13:30,  1.69s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   4%|▍         | 20/500 [00:39<12:52,  1.61s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   4%|▍         | 21/500 [00:40<12:33,  1.57s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   4%|▍         | 22/500 [00:42<12:42,  1.60s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   5%|▍         | 23/500 [00:43<12:00,  1.51s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   5%|▍         | 24/500 [00:45<12:33,  1.58s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   5%|▌         | 25/500 [00:47<13:48,  1.75s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   5%|▌         | 26/500 [00:49<13:12,  1.67s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   5%|▌         | 27/500 [00:51<13:34,  1.72s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   6%|▌         | 28/500 [00:52<13:19,  1.69s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   6%|▌         | 29/500 [00:54<13:37,  1.74s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   6%|▌         | 30/500 [00:56<13:14,  1.69s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   6%|▌         | 31/500 [00:57<13:03,  1.67s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   6%|▋         | 32/500 [00:59<13:01,  1.67s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   7%|▋         | 33/500 [01:01<14:19,  1.84s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   7%|▋         | 34/500 [01:03<13:41,  1.76s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   7%|▋         | 35/500 [01:04<12:32,  1.62s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   7%|▋         | 36/500 [01:06<12:56,  1.67s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   7%|▋         | 37/500 [01:07<11:22,  1.47s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   8%|▊         | 38/500 [01:09<12:27,  1.62s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   8%|▊         | 39/500 [01:11<12:44,  1.66s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   8%|▊         | 40/500 [01:12<12:05,  1.58s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   8%|▊         | 41/500 [01:14<12:26,  1.63s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   8%|▊         | 42/500 [01:15<11:40,  1.53s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   9%|▊         | 43/500 [01:17<11:50,  1.55s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   9%|▉         | 44/500 [01:18<11:04,  1.46s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   9%|▉         | 45/500 [01:19<11:00,  1.45s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   9%|▉         | 46/500 [01:21<10:58,  1.45s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   9%|▉         | 47/500 [01:22<11:06,  1.47s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  10%|▉         | 48/500 [01:24<11:39,  1.55s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  10%|▉         | 49/500 [01:26<12:12,  1.62s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  10%|█         | 50/500 [01:27<12:31,  1.67s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  10%|█         | 51/500 [01:29<11:48,  1.58s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  10%|█         | 52/500 [01:31<12:19,  1.65s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  11%|█         | 53/500 [01:32<11:48,  1.59s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  11%|█         | 54/500 [01:33<10:55,  1.47s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  11%|█         | 55/500 [01:36<13:55,  1.88s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  11%|█         | 56/500 [01:37<11:23,  1.54s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  11%|█▏        | 57/500 [01:39<12:43,  1.72s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  12%|█▏        | 58/500 [01:40<10:34,  1.43s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  12%|█▏        | 59/500 [01:41<10:55,  1.49s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  12%|█▏        | 60/500 [01:43<10:36,  1.45s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  12%|█▏        | 61/500 [01:44<10:39,  1.46s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  12%|█▏        | 62/500 [01:46<10:22,  1.42s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  13%|█▎        | 63/500 [01:47<11:10,  1.54s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  13%|█▎        | 64/500 [01:48<09:59,  1.37s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  13%|█▎        | 65/500 [01:50<10:35,  1.46s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  13%|█▎        | 66/500 [01:52<11:36,  1.60s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  13%|█▎        | 67/500 [01:54<11:33,  1.60s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  14%|█▎        | 68/500 [01:55<11:53,  1.65s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  14%|█▍        | 69/500 [01:57<12:00,  1.67s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  14%|█▍        | 70/500 [01:59<12:16,  1.71s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  14%|█▍        | 71/500 [02:00<11:59,  1.68s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  14%|█▍        | 72/500 [02:02<12:09,  1.70s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  15%|█▍        | 73/500 [02:04<11:58,  1.68s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  15%|█▍        | 74/500 [02:05<11:45,  1.66s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  15%|█▌        | 75/500 [02:07<11:51,  1.67s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  15%|█▌        | 76/500 [02:09<12:47,  1.81s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  15%|█▌        | 77/500 [02:11<12:34,  1.78s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  16%|█▌        | 78/500 [02:13<12:13,  1.74s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  16%|█▌        | 79/500 [02:14<11:45,  1.68s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  16%|█▌        | 80/500 [02:16<11:41,  1.67s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  16%|█▌        | 81/500 [02:17<11:12,  1.60s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  16%|█▋        | 82/500 [02:19<10:56,  1.57s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  17%|█▋        | 83/500 [02:20<10:02,  1.44s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  17%|█▋        | 84/500 [02:21<10:15,  1.48s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  17%|█▋        | 85/500 [02:24<12:41,  1.84s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  17%|█▋        | 86/500 [02:26<11:43,  1.70s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  17%|█▋        | 87/500 [02:27<11:37,  1.69s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  18%|█▊        | 88/500 [02:29<11:33,  1.68s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  18%|█▊        | 89/500 [02:30<11:18,  1.65s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  18%|█▊        | 90/500 [02:32<11:09,  1.63s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  18%|█▊        | 91/500 [02:34<11:09,  1.64s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  18%|█▊        | 92/500 [02:36<11:35,  1.70s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  19%|█▊        | 93/500 [02:37<10:15,  1.51s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  19%|█▉        | 94/500 [02:38<10:35,  1.57s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  19%|█▉        | 95/500 [02:40<10:50,  1.61s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  19%|█▉        | 96/500 [02:41<10:14,  1.52s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  19%|█▉        | 97/500 [02:44<12:21,  1.84s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  20%|█▉        | 98/500 [02:45<10:44,  1.60s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  20%|█▉        | 99/500 [02:47<10:41,  1.60s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  20%|██        | 100/500 [02:48<10:34,  1.59s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  20%|██        | 101/500 [02:49<09:55,  1.49s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  20%|██        | 102/500 [02:51<09:51,  1.49s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  21%|██        | 103/500 [02:52<09:54,  1.50s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  21%|██        | 104/500 [02:54<10:54,  1.65s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  21%|██        | 105/500 [02:56<10:36,  1.61s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  21%|██        | 106/500 [02:57<10:09,  1.55s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  21%|██▏       | 107/500 [02:59<10:24,  1.59s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  22%|██▏       | 108/500 [03:01<10:45,  1.65s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  22%|██▏       | 109/500 [03:02<09:52,  1.52s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  22%|██▏       | 110/500 [03:04<09:59,  1.54s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  22%|██▏       | 111/500 [03:05<10:04,  1.55s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  22%|██▏       | 112/500 [03:07<10:20,  1.60s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  23%|██▎       | 113/500 [03:09<10:51,  1.68s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  23%|██▎       | 114/500 [03:10<10:01,  1.56s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  23%|██▎       | 115/500 [03:12<10:11,  1.59s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  23%|██▎       | 116/500 [03:13<10:02,  1.57s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  23%|██▎       | 117/500 [03:15<09:53,  1.55s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  24%|██▎       | 118/500 [03:17<10:34,  1.66s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  24%|██▍       | 119/500 [03:18<10:11,  1.61s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  24%|██▍       | 120/500 [03:19<09:42,  1.53s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  24%|██▍       | 121/500 [03:21<10:08,  1.60s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  24%|██▍       | 122/500 [03:22<09:25,  1.49s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  25%|██▍       | 123/500 [03:24<09:20,  1.49s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  25%|██▍       | 124/500 [03:26<09:37,  1.54s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  25%|██▌       | 125/500 [03:27<09:30,  1.52s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  25%|██▌       | 126/500 [03:29<10:04,  1.62s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  25%|██▌       | 127/500 [03:30<09:55,  1.60s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  26%|██▌       | 128/500 [03:32<10:14,  1.65s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  26%|██▌       | 129/500 [03:34<10:05,  1.63s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  26%|██▌       | 130/500 [03:35<10:01,  1.63s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  26%|██▌       | 131/500 [03:37<09:49,  1.60s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  26%|██▋       | 132/500 [03:39<09:59,  1.63s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  27%|██▋       | 133/500 [03:40<09:25,  1.54s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  27%|██▋       | 134/500 [03:42<09:54,  1.63s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  27%|██▋       | 135/500 [03:43<09:34,  1.57s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  27%|██▋       | 136/500 [03:45<09:53,  1.63s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  27%|██▋       | 137/500 [03:47<10:03,  1.66s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  28%|██▊       | 138/500 [03:49<10:21,  1.72s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  28%|██▊       | 139/500 [03:50<09:36,  1.60s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  28%|██▊       | 140/500 [03:51<09:25,  1.57s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  28%|██▊       | 141/500 [03:54<10:19,  1.73s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  28%|██▊       | 142/500 [03:54<08:27,  1.42s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# ...
# Evaluating:  91%|█████████▏| 457/500 [12:13<01:07,  1.56s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  92%|█████████▏| 458/500 [12:15<01:09,  1.64s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  92%|█████████▏| 459/500 [12:16<01:05,  1.59s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  92%|█████████▏| 460/500 [12:18<01:02,  1.56s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  92%|█████████▏| 461/500 [12:19<01:00,  1.56s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  92%|█████████▏| 462/500 [12:21<00:58,  1.53s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  93%|█████████▎| 463/500 [12:22<00:58,  1.58s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  93%|█████████▎| 464/500 [12:24<01:00,  1.69s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  93%|█████████▎| 465/500 [12:25<00:51,  1.48s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  93%|█████████▎| 466/500 [12:27<00:53,  1.58s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  93%|█████████▎| 467/500 [12:29<00:51,  1.56s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  94%|█████████▎| 468/500 [12:31<00:52,  1.64s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  94%|█████████▍| 469/500 [12:32<00:49,  1.60s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  94%|█████████▍| 470/500 [12:34<00:47,  1.58s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  94%|█████████▍| 471/500 [12:35<00:46,  1.60s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  94%|█████████▍| 472/500 [12:37<00:47,  1.69s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  95%|█████████▍| 473/500 [12:39<00:43,  1.62s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  95%|█████████▍| 474/500 [12:40<00:39,  1.50s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  95%|█████████▌| 475/500 [12:41<00:39,  1.56s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  95%|█████████▌| 476/500 [12:43<00:37,  1.55s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  95%|█████████▌| 477/500 [12:44<00:33,  1.45s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  96%|█████████▌| 478/500 [12:46<00:34,  1.56s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  96%|█████████▌| 479/500 [12:48<00:32,  1.56s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  96%|█████████▌| 480/500 [12:50<00:33,  1.68s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  96%|█████████▌| 481/500 [12:51<00:31,  1.65s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  96%|█████████▋| 482/500 [12:52<00:26,  1.45s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  97%|█████████▋| 483/500 [12:54<00:25,  1.49s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  97%|█████████▋| 484/500 [12:55<00:24,  1.51s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  97%|█████████▋| 485/500 [12:56<00:20,  1.36s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  97%|█████████▋| 486/500 [12:58<00:21,  1.53s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  97%|█████████▋| 487/500 [12:59<00:18,  1.41s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  98%|█████████▊| 488/500 [13:01<00:16,  1.38s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  98%|█████████▊| 489/500 [13:02<00:15,  1.45s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  98%|█████████▊| 490/500 [13:03<00:13,  1.34s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  98%|█████████▊| 491/500 [13:05<00:13,  1.49s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  98%|█████████▊| 492/500 [13:07<00:12,  1.56s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  99%|█████████▊| 493/500 [13:08<00:10,  1.46s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  99%|█████████▉| 494/500 [13:10<00:09,  1.54s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  99%|█████████▉| 495/500 [13:11<00:07,  1.51s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  99%|█████████▉| 496/500 [13:13<00:06,  1.53s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  99%|█████████▉| 497/500 [13:14<00:04,  1.48s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating: 100%|█████████▉| 498/500 [13:15<00:02,  1.34s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating: 100%|█████████▉| 499/500 [13:17<00:01,  1.39s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating: 100%|██████████| 500/500 [13:18<00:00,  1.60s/it]
# ✅ Evaluation completed!
#                                                claim    label  \
# 0        35% of revenue goes to states. (In Nigeria)  Refuted
# 1  The Common Law Admission Test (CLAT) 2020 will...  Refuted
# 2  Donald Trump delivered the largest tax cuts in...  Refuted
# 3  After the police shooting of Jacob Blake, Gov....  Refuted
# 4         Biden will take away the Second Amendment.  Refuted
#
#                                        justification label_pred  \
# 0  The answer shows that 26.72% goes to states so...    Refuted
# 1  The answer and credible source show that the c...    Refuted
# 2  Three tax bills have been larger than that of ...    Refuted
# 3  Governor Evers did call for peace in a video s...    Refuted
# 4        Biden does not want to end second amendment    Refuted
#
#                                   justification_pred  rougeL_f1      bleu  \
# 0  According to the Nigerian National Bureau of S...   0.081633  1.235039
# 1  The Common Law Admission Test (CLAT) 2020 was ...   0.140351  1.279087
# 2  While the Tax Cuts and Jobs Act of 2017 did in...   0.062500  0.718846
# 3  Immediately following the shooting of Jacob Bl...   0.126984  0.838553
# 4  President Biden has repeatedly stated his supp...   0.140351  0.832775
#
#      cosine  bertscore_f1
# 0  0.284774      0.178510
# 1  0.087320      0.065769
# 2  0.564513     -0.034126
# 3  0.529204      0.255077
# 4  0.686665      0.259683

# %%
  # <-- set to your JSON file (array or JSONL)
MODEL = ("mistral:7b").strip()         # e.g., "qwen3:4b", "mistral:7b", "gemma3:4b"
          

results = []
with concurrent.futures.ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
    futures = {executor.submit(safe_ask_ollama, row): row for row in subset}
    for future in tqdm(concurrent.futures.as_completed(futures), total=len(futures), desc="Evaluating"):
        try:
            result = future.result(timeout=MODEL_TIMEOUT)
            results.append(result)
        except concurrent.futures.TimeoutError:
            claim = futures[future]["claim"]
            print(f"⚠️ Timeout for claim: {claim[:60]}...")
            results.append({
                "claim": claim,
                "error": "Timeout"
            })

# --- Combine results ---
df = pd.DataFrame(results)

# --- Save to CSV for safety ---
df.to_csv("ollama_eval_results_mistral.csv", index=False)

print("✅ Evaluation completed!")
df.head()         # language code for BERTScore baseline rescaling
# Out:
# Evaluating:   0%|          | 0/500 [00:00<?, ?it/s]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   0%|          | 1/500 [00:10<1:28:14, 10.61s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   0%|          | 2/500 [00:12<43:39,  5.26s/it]  Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   1%|          | 3/500 [00:14<34:25,  4.16s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   1%|          | 4/500 [00:17<29:43,  3.60s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   1%|          | 5/500 [00:19<22:57,  2.78s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   1%|          | 6/500 [00:20<19:27,  2.36s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   1%|▏         | 7/500 [00:22<17:44,  2.16s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   2%|▏         | 8/500 [00:23<15:57,  1.95s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   2%|▏         | 9/500 [00:25<15:22,  1.88s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   2%|▏         | 10/500 [00:27<14:29,  1.77s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   2%|▏         | 11/500 [00:28<13:39,  1.68s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   2%|▏         | 12/500 [00:31<15:34,  1.92s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   3%|▎         | 13/500 [00:33<15:47,  1.95s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   3%|▎         | 14/500 [00:34<15:26,  1.91s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   3%|▎         | 15/500 [00:37<16:36,  2.06s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   3%|▎         | 16/500 [00:38<14:16,  1.77s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   3%|▎         | 17/500 [00:39<13:29,  1.68s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   4%|▎         | 18/500 [00:41<13:36,  1.69s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   4%|▍         | 19/500 [00:44<15:31,  1.94s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   4%|▍         | 20/500 [00:46<17:07,  2.14s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   4%|▍         | 21/500 [00:48<16:42,  2.09s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   4%|▍         | 22/500 [00:50<15:15,  1.92s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   5%|▍         | 23/500 [00:51<13:48,  1.74s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   5%|▍         | 24/500 [00:53<15:15,  1.92s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   5%|▌         | 25/500 [00:55<15:14,  1.92s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   5%|▌         | 26/500 [00:58<17:22,  2.20s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   5%|▌         | 27/500 [00:59<15:21,  1.95s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   6%|▌         | 28/500 [01:01<14:25,  1.83s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   6%|▌         | 29/500 [01:03<14:08,  1.80s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   6%|▌         | 30/500 [01:04<12:35,  1.61s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   6%|▌         | 31/500 [01:06<12:43,  1.63s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   6%|▋         | 32/500 [01:08<14:50,  1.90s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   7%|▋         | 33/500 [01:11<16:31,  2.12s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   7%|▋         | 34/500 [01:12<15:10,  1.95s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   7%|▋         | 35/500 [01:15<16:37,  2.15s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   7%|▋         | 36/500 [01:17<16:43,  2.16s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   7%|▋         | 37/500 [01:18<14:37,  1.89s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   8%|▊         | 38/500 [01:20<14:42,  1.91s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   8%|▊         | 39/500 [01:22<13:34,  1.77s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   8%|▊         | 40/500 [01:23<12:07,  1.58s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   8%|▊         | 42/500 [01:25<09:35,  1.26s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   9%|▊         | 43/500 [01:28<13:55,  1.83s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   9%|▉         | 44/500 [01:30<12:43,  1.67s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   9%|▉         | 45/500 [01:31<11:50,  1.56s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   9%|▉         | 46/500 [01:32<11:28,  1.52s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:   9%|▉         | 47/500 [01:34<11:38,  1.54s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  10%|▉         | 48/500 [01:36<12:19,  1.64s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  10%|▉         | 49/500 [01:38<12:45,  1.70s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  10%|█         | 50/500 [01:39<11:34,  1.54s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  10%|█         | 51/500 [01:41<13:09,  1.76s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  10%|█         | 52/500 [01:42<12:21,  1.65s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  11%|█         | 53/500 [01:43<10:54,  1.46s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  11%|█         | 54/500 [01:46<13:11,  1.77s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  11%|█         | 55/500 [01:49<16:47,  2.26s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  11%|█         | 56/500 [01:51<14:48,  2.00s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  11%|█▏        | 57/500 [01:53<14:54,  2.02s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  12%|█▏        | 58/500 [01:55<16:05,  2.18s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  12%|█▏        | 59/500 [01:57<13:54,  1.89s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  12%|█▏        | 60/500 [01:59<14:56,  2.04s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  12%|█▏        | 61/500 [02:01<14:30,  1.98s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  12%|█▏        | 62/500 [02:02<12:53,  1.77s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  13%|█▎        | 63/500 [02:05<14:26,  1.98s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  13%|█▎        | 64/500 [02:06<13:08,  1.81s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  13%|█▎        | 65/500 [02:07<11:15,  1.55s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  13%|█▎        | 66/500 [02:11<16:21,  2.26s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  13%|█▎        | 67/500 [02:12<13:15,  1.84s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  14%|█▎        | 68/500 [02:13<12:33,  1.75s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  14%|█▍        | 69/500 [02:15<13:08,  1.83s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  14%|█▍        | 70/500 [02:18<15:55,  2.22s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  14%|█▍        | 71/500 [02:20<15:40,  2.19s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  14%|█▍        | 72/500 [02:23<16:09,  2.26s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  15%|█▍        | 73/500 [02:25<15:29,  2.18s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  15%|█▍        | 74/500 [02:26<14:03,  1.98s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  15%|█▌        | 75/500 [02:29<14:45,  2.08s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  15%|█▌        | 76/500 [02:31<15:06,  2.14s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  15%|█▌        | 77/500 [02:34<17:06,  2.43s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  16%|█▌        | 78/500 [02:35<14:21,  2.04s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  16%|█▌        | 79/500 [02:38<15:42,  2.24s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  16%|█▌        | 80/500 [02:40<14:46,  2.11s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  16%|█▌        | 81/500 [02:42<14:43,  2.11s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  16%|█▋        | 82/500 [02:44<15:08,  2.17s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  17%|█▋        | 83/500 [02:46<14:31,  2.09s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  17%|█▋        | 84/500 [02:47<13:04,  1.89s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  17%|█▋        | 85/500 [02:50<13:39,  1.98s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  17%|█▋        | 86/500 [02:51<12:50,  1.86s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  17%|█▋        | 87/500 [02:53<13:16,  1.93s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  18%|█▊        | 88/500 [02:56<15:39,  2.28s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  18%|█▊        | 89/500 [02:57<13:00,  1.90s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  18%|█▊        | 90/500 [02:59<12:22,  1.81s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  18%|█▊        | 91/500 [03:02<13:41,  2.01s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  18%|█▊        | 92/500 [03:03<13:35,  2.00s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  19%|█▊        | 93/500 [03:05<12:41,  1.87s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  19%|█▉        | 94/500 [03:07<13:46,  2.04s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  19%|█▉        | 95/500 [03:09<13:12,  1.96s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  19%|█▉        | 96/500 [03:12<14:10,  2.11s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  19%|█▉        | 97/500 [03:14<14:47,  2.20s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  20%|█▉        | 98/500 [03:16<13:17,  1.98s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  20%|█▉        | 99/500 [03:18<14:41,  2.20s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  20%|██        | 100/500 [03:19<12:37,  1.89s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  20%|██        | 101/500 [03:20<10:33,  1.59s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  20%|██        | 102/500 [03:22<11:30,  1.73s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  21%|██        | 103/500 [03:24<10:51,  1.64s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  21%|██        | 104/500 [03:26<11:03,  1.67s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  21%|██        | 105/500 [03:27<10:59,  1.67s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  21%|██        | 106/500 [03:30<13:41,  2.08s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  21%|██▏       | 107/500 [03:32<12:11,  1.86s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  22%|██▏       | 108/500 [03:33<10:27,  1.60s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  22%|██▏       | 109/500 [03:34<10:42,  1.64s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  22%|██▏       | 110/500 [03:36<10:46,  1.66s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  22%|██▏       | 111/500 [03:38<11:29,  1.77s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  22%|██▏       | 112/500 [03:40<12:14,  1.89s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  23%|██▎       | 113/500 [03:42<12:08,  1.88s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  23%|██▎       | 114/500 [03:43<10:35,  1.65s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  23%|██▎       | 115/500 [03:46<12:11,  1.90s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  23%|██▎       | 116/500 [03:49<14:01,  2.19s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  23%|██▎       | 117/500 [03:50<12:26,  1.95s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  24%|██▎       | 118/500 [03:53<14:42,  2.31s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  24%|██▍       | 119/500 [03:54<11:56,  1.88s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  24%|██▍       | 120/500 [03:57<13:16,  2.10s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  24%|██▍       | 121/500 [04:00<15:04,  2.39s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  24%|██▍       | 122/500 [04:01<13:02,  2.07s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  25%|██▍       | 123/500 [04:03<11:58,  1.90s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  25%|██▍       | 124/500 [04:04<11:52,  1.90s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  25%|██▌       | 125/500 [04:07<12:15,  1.96s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  25%|██▌       | 126/500 [04:09<13:43,  2.20s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  25%|██▌       | 127/500 [04:11<12:00,  1.93s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  26%|██▌       | 128/500 [04:13<12:41,  2.05s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  26%|██▌       | 129/500 [04:16<14:26,  2.34s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  26%|██▌       | 130/500 [04:18<13:19,  2.16s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  26%|██▌       | 131/500 [04:19<11:00,  1.79s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  26%|██▋       | 132/500 [04:21<11:18,  1.84s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  27%|██▋       | 133/500 [04:22<11:19,  1.85s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  27%|██▋       | 134/500 [04:25<12:37,  2.07s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  27%|██▋       | 135/500 [04:27<11:37,  1.91s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  27%|██▋       | 136/500 [04:29<11:54,  1.96s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  27%|██▋       | 137/500 [04:30<11:24,  1.89s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  28%|██▊       | 138/500 [04:32<11:20,  1.88s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  28%|██▊       | 139/500 [04:34<11:11,  1.86s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  28%|██▊       | 140/500 [04:35<09:44,  1.62s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  28%|██▊       | 141/500 [04:37<10:40,  1.79s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  28%|██▊       | 142/500 [04:39<10:34,  1.77s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  29%|██▊       | 143/500 [04:41<11:06,  1.87s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# ...
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  91%|█████████ | 455/500 [14:50<01:23,  1.85s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  91%|█████████ | 456/500 [14:52<01:34,  2.15s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  91%|█████████▏| 457/500 [14:54<01:22,  1.92s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  92%|█████████▏| 458/500 [14:56<01:24,  2.02s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  92%|█████████▏| 459/500 [14:58<01:21,  1.98s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  92%|█████████▏| 460/500 [14:59<01:08,  1.71s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  92%|█████████▏| 461/500 [15:02<01:18,  2.02s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  92%|█████████▏| 462/500 [15:04<01:14,  1.96s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  93%|█████████▎| 463/500 [15:07<01:23,  2.27s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  93%|█████████▎| 464/500 [15:08<01:11,  1.99s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  93%|█████████▎| 465/500 [15:10<01:14,  2.13s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  93%|█████████▎| 466/500 [15:12<01:04,  1.91s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  93%|█████████▎| 467/500 [15:13<00:58,  1.77s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  94%|█████████▎| 468/500 [15:15<00:58,  1.84s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  94%|█████████▍| 469/500 [15:17<01:01,  1.99s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  94%|█████████▍| 470/500 [15:19<00:57,  1.92s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  94%|█████████▍| 471/500 [15:21<00:54,  1.86s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  94%|█████████▍| 472/500 [15:23<00:56,  2.01s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  95%|█████████▍| 473/500 [15:26<00:57,  2.13s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  95%|█████████▍| 474/500 [15:27<00:47,  1.83s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  95%|█████████▌| 475/500 [15:29<00:48,  1.94s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  95%|█████████▌| 476/500 [15:31<00:49,  2.06s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  95%|█████████▌| 477/500 [15:32<00:39,  1.72s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  96%|█████████▌| 478/500 [15:34<00:39,  1.79s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  96%|█████████▌| 479/500 [15:36<00:35,  1.70s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  96%|█████████▋| 482/500 [15:41<00:30,  1.70s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  97%|█████████▋| 483/500 [15:44<00:38,  2.25s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  97%|█████████▋| 484/500 [15:46<00:31,  1.96s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  97%|█████████▋| 485/500 [15:47<00:27,  1.84s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  97%|█████████▋| 486/500 [15:49<00:25,  1.82s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  97%|█████████▋| 487/500 [15:50<00:21,  1.62s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  98%|█████████▊| 488/500 [15:52<00:21,  1.78s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  98%|█████████▊| 490/500 [15:55<00:14,  1.47s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  98%|█████████▊| 491/500 [15:59<00:20,  2.23s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  98%|█████████▊| 492/500 [16:01<00:17,  2.18s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  99%|█████████▊| 493/500 [16:03<00:14,  2.00s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  99%|█████████▉| 494/500 [16:04<00:11,  1.89s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  99%|█████████▉| 495/500 [16:05<00:08,  1.67s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  99%|█████████▉| 496/500 [16:06<00:05,  1.47s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating:  99%|█████████▉| 497/500 [16:07<00:04,  1.38s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating: 100%|█████████▉| 498/500 [16:09<00:03,  1.50s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating: 100%|█████████▉| 499/500 [16:11<00:01,  1.48s/it]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating: 100%|██████████| 500/500 [16:13<00:00,  1.95s/it]
# ✅ Evaluation completed!
#                                                claim    label  \
# 0        35% of revenue goes to states. (In Nigeria)  Refuted
# 1  The Common Law Admission Test (CLAT) 2020 will...  Refuted
# 2  After the police shooting of Jacob Blake, Gov....  Refuted
# 3  Donald Trump delivered the largest tax cuts in...  Refuted
# 4         Biden will take away the Second Amendment.  Refuted
#
#                                        justification label_pred  \
# 0  The answer shows that 26.72% goes to states so...    Refuted
# 1  The answer and credible source show that the c...    Refuted
# 2  Governor Evers did call for peace in a video s...    Refuted
# 3  Three tax bills have been larger than that of ...    Refuted
# 4        Biden does not want to end second amendment    Refuted
#
#                                   justification_pred  rougeL_f1      bleu  \
# 0  According to the Nigerian National Bureau of S...   0.145455  2.380649
# 1  The CLAT 2020 was indeed conducted on Septembe...   0.136364  1.856467
# 2  On August 24th, 2020, following the police sho...   0.196721  1.111651
# 3  The Tax Cuts and Jobs Act of 2017, signed by P...   0.086957  0.751986
# 4  Biden has stated multiple times that he does n...   0.263158  2.567439
#
#      cosine  bertscore_f1 error
# 0  0.238661      0.103189   NaN
# 1  0.106118      0.035076   NaN
# 2  0.580175      0.226804   NaN
# 3  0.552010      0.016500   NaN
# 4  0.744294      0.354423   NaN
